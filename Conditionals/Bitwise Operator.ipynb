# %%
a = 25
bin(a)
# Out:
# '0b11001'

# %%
format(a,'b')
# Out:
# '11001'

# %%
a.bit_length()
# Out:
# 5

# %%
print(10 & 13)
format(8,'b')
# Out:
# 8
# '1000'

# %%
10 | 13
format(15,'b')
# Out:
# '1111'

# %%
10 ^ 13
format(7,'b')
# Out:
# '111'

# %%
print(10 << 1)
print(10 << 2)
print(10 << 5)
# Out:
# 20
# 40
# 320

# %%
print(10 >> 1)
print(5 >> 1)
print(10 >> 2)
# Out:
# 5
# 2
# 2
