# %% [markdown]
# ## String Comparison

# %%
s1 = 'software'
s2 = 'Hardwaere'
print(s1 > s2)

s3 = 'python'
s4 = 'pycharm'
print(s3 < s4)

s5 = 'integer'
s6 = 'integer'
print(s5 == s6)

s7 = 'printer'
s8 = 'print'
print(s7 > s8)
# Out:
# True
# False
# True
# True
