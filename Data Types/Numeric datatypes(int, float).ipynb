# %%
x = 101
y = 123456789012345
print(x)
print(y)
# Out:
# 101
# 123456789012345

# %%
import sys
sys.getsizeof(x)
# Out:
# 28

# %%
sys.getsizeof(y)
# Out:
# 32

# %%
x = 101
print(id(x))
# Out:
# 140704704712744

# %%
x = 205
print(id(x))
# Out:
# 140704704716072

# %%
a = 29.75
b = -1.75
c = -2.5E2
d = -3.1e-2

print(a,b,c,d)
# Out:
# 29.75 -1.75 -250.0 -0.031
