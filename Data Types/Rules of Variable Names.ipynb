# %% [markdown]
# ## Rules
#
# - Should be Meaningful
# - Alphanumeric & Underscore
# - Start with Letter or Underscore
# - Not a Keyword
# - Case Sensitive

# %%
## 1.
prod_id = 153
cust_name = 'Smith'
cust_city = 'New York'

# %%
##2. 
a1 = 100
cust_names = 'James'
#cust-name = 'James'
#cust name = 'James'
print(a1)
# Out:
# 100

# %%
##3.
address1 = 'Delhi'
#1address = 'Delhi'
_address = 'Delhi'
#None = 'Delhi'
print(_address)
# Out:
# Delhi

# %% [markdown]
# #### Keywords
# - None
# - False
# - and
# - True
# - as
# - async
# - assert
# - break
# - await
# - continue
# - class
# - def
# - elif
# - del
# - except
# - else
# - for
# - finally
# - from
# - if
# - global
# - in
# - import
# - lambda
# - is
# - nonlocal
# - not
# - or
# - raise
# - pass
# - try
# - return
# - while
# - with
# - yield

# %%
##4.
#if = 20
#False = 'Yes'
false = 'Yes'

# %%
##5.
cost = 19.99
Cost = 29.99
COST = 199.99
