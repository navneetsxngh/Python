# %%
a = 201
b = 135_246_198
print(a,b)
# Out:
# 201 135246198

# %%
a = 9.75
b = 15.0
print(a,b)
# Out:
# 9.75 15.0

# %%
type(b)
c = 12e2
d = 12.5e-2
print(c,d)
# Out:
# 1200.0 0.125

# %%
e = 12_5.6_7
print(e)
# Out:
# 125.67

# %%
f = 5_._9
# Out:
#   Cell In[5], line 1
#     f = 5_._9
#          ^
# SyntaxError: invalid decimal literal

# %%
a = 4 + 5j
b = 1_2 + 1_4j
c = 1.4 + 2.5j
print(a)
print(b)
print(c)
# Out:
# (4+5j)
# (12+14j)
# (1.4+2.5j)

# %%
name1 = 'Alexa'
name2 = "Alexa"
name3 = '"Alexa"'

print(name1, name2, name3)
# Out:
# Alexa Alexa "Alexa"
