# %% [markdown]
# ## LIST

# %%
##List in Python ---> This is a container in which we can store our elements.
# Identification = []
# Indexing starts from zero and length starts from 1.
# Mutable data Type ---> We can change or update our values at a runtime.

# %%
a = ['sam', 45, 56.90, 'Rahul']
print(a)
print(type(a))
# Out:
# ['sam', 45, 56.9, 'Rahul']
# <class 'list'>

# %%
## Indexing
print(a[0])             ##Forward Indexing
print(a[1])
print(a[2])
print(a[3])
print("------------------------")
print(a[-1])            ##Reverse Indexing
print(a[-2])
print(a[-3])
print(a[-4])

# %%
## Slicing in List
b = ['sam',45,56.90,'Rahul',[12,'raj',78.56]]
print(b)
# Out:
# ['sam', 45, 56.9, 'Rahul', [12, 'raj', 78.56]]

# %%
print(b[0:2])
print(b[1:4])
print(b[2:])
print(b[:2])
print(b[:])
print(b[-1::-1])
print(b[3][2])
print(b[4][1][1])
# Out:
# ['sam', 45]
# [45, 56.9, 'Rahul']
# [56.9, 'Rahul', [12, 'raj', 78.56]]
# ['sam', 45]
# ['sam', 45, 56.9, 'Rahul', [12, 'raj', 78.56]]
# [[12, 'raj', 78.56], 'Rahul', 56.9, 45, 'sam']
# h
# a

# %%
## List Mutable data Type
c = ['sam', 45, 56.90, 'Rahul']
c[3] = 'Python'
print(c)

# %%
## Loop in List
d = ['sam', 45, 58.90, 'Rahul']
for i in d:
    print(i, end=" ")

# %%
for i in range(len(a)):
    print(d[i], end=" ")

# %%
## Properties of List--->
# (1). Concatenation
e = [1,2,3]
f = [4,5,6]
g = e + f
print(g)

# %%
# (2). Replication
h = [1,2,3]
print(h*3)

# %%
## Functions in List
d = ['sam', 45, 58.90, 'Rahul']
#(1). len() ---> It will return length of a list.
len(d)

# %%
# (2). index() ---> It will return indexing of an element.
d = ['sam', 45, 58.90, 'Rahul']
d.index('Rahul')

# %%
# (3). append() ---> It will add an element in the last indexing.
e = []
print(e)
e.append('Maths')
print(e)
e.append('Physics')
print(e)
e.append("Chemistry")
print(e)

# %%
# (4). insert() ---> It will add an element at any indexing of a list.
d = ['sam', 45, 58.90, 'Rahul']
print(d)
#d.insert(index, element)
d.insert(1,900)
print(d)
d.insert(1,5000)
print(d)

# %%
# (5). pop() ---> It will remove last element of a list
d = ['sam', 45, 58.90, 'Rahul']
d.pop()
print(d)
d.pop
print(d)
d.pop()
print(d)
d.pop()
print(d)
d.pop()
print(d)

# %%
# (6). remove()---> It will remove a specific element from a list
d = ['sam', 45, 58.90, 'Rahul']
print(d)
d.remove(45)
print(d)
d.remove(58.90)
print(d)

# %%
# (7). reverse() ----> It will reverse a list
d = ['sam', 45, 58.90, 'Rahul']
print(d)
d.reverse()
print(d)

# %%
# (8). sort() ----> It will arrange our element in ascending order
f = [1,56,23,89,60]
print(f)
f.sort()
print(f)
f.reverse()
print(f)
# Out:
# [1, 56, 23, 89, 60]
# [1, 23, 56, 60, 89]
# [89, 60, 56, 23, 1]

# %%
# (9). count()---> It will return frequency of an element.
g = ['sam', 45, 98.60, 'Rahul', 45,45,45,45]
print(g)
g.count(45)

# %%
# (10). min() / max()----> It will return minimum and maximum value

h = [1,2,3,4]
print(min(h))
print(max(h))

# %% [markdown]
# #### Questions

# %%
d = ['sam', 45, 58.90, 'Rahul']

alphabets = []
numbers = []

for item in d:
    if str(item).isalpha():   
        alphabets.append(item)
    else:
        numbers.append(item)

print("Alphabets List:", alphabets)
print("Numbers List:", numbers)

# %%
# Q(1). Create a user defined list and then you have to do sum of the numbers.

a = []
size = int(input("Enter Size of the List: "))
for i in range(size):
    val = int(input("Enter Number: "))
    a.append(val)
print(a)
sum = 0
for i in range(len(a)):
    sum += a[i]
print("Sum of the numbers in a list is: ", sum)

# %%
# Q(2). Maximum Number.
a = []
size = int(input("Enter Size of the list: "))
for i in range(size):
    val = int(input("Enter Number: "))
    a.append(val)
print(a)
max = a[0]
for i in range(len(a)):
    if a[i] > max:
        max = a[i]
print("Max number is: ", max)

# %%
# Q3. Find the Missing Number.
a = []
size = int(input("Enter Size of the List: "))
for i in range(size):
    val = int(input("Enter Number: "))
    a.append(val)
print(a)

total_sum = 0
for i in range(1, size+2):
    total_sum += i
print("Total= ", total_sum)

list_sum = 0
for n in a:
    list_sum += n
print("List = ", list_sum)

missing = total_sum - list_sum
print("The Missing Number is: ", missing)

# %%
# Q4. Common Element from two lists.
a = [1,2,3,4,5,6,7,8]
b = [3,4,5,6,9,15]
c = []
for i in a:
    if i in b:
        c.append(i)
print(c)

# %%
# Q5. Remove dupicate elements in a list.
a = [1,2,2,3,3,3,4,4,4,4,5,6]
b = []
for i in a:
    if i not in b:
        b.append(i)
print(a)
print(b)

# %%
# Q6. Create a user defined list and then you have to create an another list in which you will store your unique elements and
#  then you have to find maximum, second maximum number and then you have to find total sum of unique list.
a = []
size = int(input("Enter Size of the list: "))

for i in range(size):
    val = int(input("Enter Number: "))
    a.append(val)
print(a)

b = []
for i in a:
    if i not in b:
        b.append(i)
print("Unique list= ", b)

max = b[0]

for i in range(len(b)):
    if b[i] > max:
        max = b[i]
print("The Maximum Number is: ", max)
print("The Second maximum number is ", b[i-1])

sum = 0
for i in range(len(b)):
    sum += b[i]

print("The sum of Unique List: ", sum)

# %%
#Q7. Create a User Defined list and then reverse it using loops and check whether it is a Palindrome or not.

a = []
size = int(input("Enter size of the list: "))

for i in range(size):
    val = int(input("Enter Number: "))
    a.append(val)
original = a

print("Original: ", original)

b = []
for i in range(1,len(a)+1,):
    b.append(a[-i])
reverse = b

print("Reverse: ", reverse)

if original == reverse:
    print("Palindrome List")
else:
    print("Not Palindrome")

# %%
#Q8 . Squares and cubes of the element in a list.

a = []
size = int(input("enter the size of the list: "))

for i in range(size):
    val = int(input("Enter Number: "))
    a.append(val)

print("original list: ", a)
b = [] 
for i in range(len(a)):
    b.append(a[i]**2)

print("Squares: ", b)

c = []
for i in range(len(a)):
    c.append(a[i]**3)

print("Cubes: ",c)

# %% [markdown]
# ## LIST COMPREHENSION

# %% [markdown]
# List Comprehension in Python provide a concise way to create lists.
#
# They are more readable and efficient than Traditional for loops.
#
# Syntax:
# [expression for item in iterable if condition]

# %%
# Q1. Write a program who print lists of squares?
a = [1,2,3,4]
b = []
for i in range(len(a)):
    b.append(a[i]**2)
print("Result by using Loops: ", b)

# Using List Comprehension
squares = [i**2 for i in range(1,len(a)+1)]
print("Result by list Comprehension: ", squares)

# %%
#Nested List Comprehensions
x_vals = [1,2,3]
y_vals = [4,5,6]
pair = [(x,y) for x in x_vals for y in y_vals ]
print(pair)

# %%
# Multiplication Table
a = [f"{i} x {j} = {i*j}" for i in range(1,3) for j in range(1,11)]
# print(a)
a

# %%
# Cartesian Product with Condition
x_val = [1,2,3]
y_val = [3,4,5]
prod = [(x,y) for x in x_val for y in y_val if x+y > 5]
print(prod)

# %%
#Q2. Create a List comprehension who filters only even numbers.?
a = [i for i in range(1,11) if i % 2 == 0]
print(a)
b = [j for j in range(1,11) if j % 2 != 0]
print(b)
c = [k for k in range(1,10) if k**2 > 20]
print(c)

# %%
#Q3 . Convert all strings into uppercase.
names = ['sam', 'rohit', 'ankit']
upper_names = [i.upper() for i in names]
print(upper_names)

# %%
# Using List Comprehension and print only alphabets from string.
p = [1, 'sam', 'ankit', 56.3]

alphabets = [i for i in p if str(i).isalpha() == True]
alphabets

# %%
#Q4. Create a list of first letters of each word in a list.
a = ['sam', 'raj', 'rohit']
first = [a[i][0] for i in range(len(a))]
print(first)

# %%
#Q5. Extract all Vowels from a given string using list comprehension.
b = "I Love Python"
vowels = "aeiou"
vowel = [i for i in b if i.lower() in vowels]
print(vowel)

consonant = [i for i in b if i.lower().strip(' ') not in vowels]
print(consonant)

# %%
#Q6. Create a List of numbers divisible by 3 but not by 5 (1-50)?
num = [i for i in range(1,51) if i % 3 == 0 and i % 5 != 0]
print(num)

# %%
#Q7. Shop ----> [pen, notebook, pizza, icecream, vadapav, football, jeans, shoes, shirt]
# Filter out ----> stationary -----> [], bakery ---->[] , sports----> [], clothes ---->[]

shop = ['pen', 'notebook', 'pizza', 'icecream', 'vadapav', 'football', 'jeans', 'shoes', 'shirt']

stationary = shop[0:2]
print("Stationary Items: ",stationary)
bakery = shop[2:5]
print("Bakery Items: ",bakery)
sports = shop[5:6]
print("Sports Itmes: ",sports)
clothes = shop[6:]
print("Clothes Available: ",clothes)

# %%
# Q8. Create a list of tuples from range 1 to 5

tup = [(x,x**2) for x in range(1,6)]
print(tup)

# %%
#Q9. Extract top three longest words.
a = ['Python', 'data', 'Science', 'Machine', 'AI', 'Development']
b = []
for i in a:
    length = len(i)
    b.append(length)

b.sort()
b.reverse()

b = b[0:3]
print(b)
c = []
for i in b:
    for j in a:
        if j not in c:
            if len(j) == i:
                c.append(j)

print(c)

# %%
#Q10. Extract valid Phone Number
a = ['9568465691', '8756736723', '2345', '9579']

for i in a:
    if len(i) == 10:
        print("Valid Number: ", i)
    else:
        print("Invalid Number: ", i)

# %%
#Q11. Clean list by removing special Characters
a = ['py@thon', 'd#ata', 'sc!ience']
cleaned = []

for i in a:
    new_word = ""
    for ch in i:
        if ch.isalnum():
            new_word += ch
    cleaned.append(new_word)

print(cleaned)

# %%
moving_avg = [1,2,3,4,5,6,7,8]
i = 0
j = int(input("n"))-1
sum =0
a = []
for k in range(i,len(moving_avg)):
    print(k,end=" ")
    sum = sum + moving_avg[k] 
    if k >= j:
        a.append(sum/(j+1))
        sum = sum - moving_avg[k-j]
        i += 1
    else:
        a.append("NaN")
a

# %%
a = ["python","data","science","machine","ai","Development"]
a.sort(key = len,reverse = True)
a[0:3]
