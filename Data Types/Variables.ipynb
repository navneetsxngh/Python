# %%
length = 15
print(length)
# Out:
# 15

# %%
prices = [10,7,5,8,6]
print(prices)
# Out:
# [10, 7, 5, 8, 6]

# %%
name, price1, qty = 'Soap', 12.75, 5
print(name, price1, qty)
# Out:
# Soap 12.75 5

# %%
a, b, c = 1, 1, 1
print(id(a), id(b), id(c))
# Out:
# 140704704709544 140704704709544 140704704709544

# %%
a = b = c = 1
print(a,b,c)
# Out:
# 1 1 1

# %% [markdown]
# ### Statistically Typed language
#
# Like - C/C++/Java are statistically typed language.

# %% [markdown]
# ### Dynamically Typed Language
#
# Like- Python/Javascript

# %%
##Example - Dynamically Typed

a = 15
print(type(a))
a = 12.75
print(type(a))
a = 'John'
print(type(a))

print(a)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# John

# %%
a = [10,11,12,13]
print(type(a))
# Out:
# <class 'list'>
