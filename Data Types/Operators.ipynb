# %% [markdown]
# ## Operators

# %%
##Arithematic Operators
# '+ , -, *, /, //, %, **

# %%
##'+' Operator
print(10 + 20)
a = 10
b = 20
print(a + b)

result = a + b
print(result)
# Out:
# 30
# 30
# 30

# %%
##'-' Subtraction
a = 10
b = 5
print(a - b)
print(a * b)
print(a / b)
print(a // b)
print(a ** b)
# Out:
# 5
# 50
# 2.0
# 2
# 100000

# %%
## Write a program to print area of recatangle

length = float(input("Enter Length: "))
breadth = float(input("Enter Breadth: "))

area = length * breadth
print("The area of rectangle is: ", area)
# Out:
# The area of rectangle is:  200.0

# %%
## Area of Triangle
base = float(input("Enter Base of the traingle: "))
height = float(input('Enter the height of the triangle: '))

area = 0.5 * base * height
print("The area of the triangle is: ", area)
# Out:
# The area of the triangle is:  142.14000000000001

# %% [markdown]
# #### Shorthand Operator

# %%
a = 10
a += 5
print(a)
# Out:
# 15

# %%
a = 10
a -= 6
print(a)
# Out:
# 4

# %%
a = 10
a *= 2
print(a)
a /= 4
print(a)
a **= 2
print(a)
# Out:
# 20
# 5.0
# 25.0

# %%
#Swapping of variables
a = 10
b = 30
a = a + b  #a = 40
b = a - b  #b = 10
a = a - b  #a = 30

print(f"a : {a} b : {b}")
# Out:
# a : 30 b : 10

# %%
a ,b, c = 10 ,20, 30
a ,b = b, a
print(a,b)
# Out:
# 20 10

# %% [markdown]
# ### Membership Operator

# %%
'''
in
not in'''
#Collection
#string,list,tuple,set,dictionary
data = "Welcome to Regex"
print("t" in data)
# Out:
# True

# %%
list = [12,34,54,56,True,3.23,]
print(100 not in list)
# Out:
# True

# %%
dict = {'a' : 34 , 'b' : 56}
print('a' in dict)      ##Only look for Key.
# Out:
# True
