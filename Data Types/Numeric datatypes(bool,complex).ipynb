# %%
x = True
y = False
print(x,y)
# Out:
# True False

# %%
int(x)
# Out:
# 0

# %%
type(x)
# Out:
# bool

# %%
x = 1
type(x)
# Out:
# int

# %%
a = 10
b = 5
a > b
# Out:
# True

# %% [markdown]
# ## Complex

# %%
c = 10 + 5j
print(type(c))
# Out:
# <class 'complex'>

# %%
print(c)
# Out:
# (10+5j)

# %%
c = complex(5,3.1)
print(c)
# Out:
# (5+3.1j)

# %%
c = complex(10)
print(c)
# Out:
# (10+0j)
