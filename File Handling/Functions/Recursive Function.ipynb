# %% [markdown]
# ## Defination

# %% [markdown]
# A Recursive Function is a function that calls itself within it's own defination.

# %%
def fact(n):
    if n == 0:
        return 1
    else:
        return n * fact(n - 1)

fact(5)
# Out:
# 120
