# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\singh\OneDrive\Desktop\Python\Data\covid_toy.csv")
df.head(3)   # .head(range) shows the the first mentioned data
pd.options.display.max_rows = 9999
print(df.to_string())
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# 5    84  Female    NaN    Mild  Bangalore       Yes
# 6    14    Male  101.0  Strong  Bangalore        No
# 7    20  Female    NaN  Strong     Mumbai       Yes
# 8    19  Female  100.0  Strong  Bangalore        No
# 9    64  Female  101.0    Mild      Delhi        No
# 10   75  Female    NaN    Mild      Delhi        No
# 11   65  Female   98.0    Mild     Mumbai       Yes
# 12   25  Female   99.0  Strong    Kolkata        No
# 13   64    Male  102.0    Mild  Bangalore       Yes
# 14   51    Male  104.0    Mild  Bangalore        No
# 15   70    Male  103.0  Strong    Kolkata       Yes
# 16   69  Female  103.0    Mild    Kolkata       Yes
# ...

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df.tail()    # Shows data from the last.
# Out:
#     age  gender  fever   cough       city has_covid
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes

# %%
df.describe()   # It describes the data
# Out:
#               age       fever
# count  100.000000   90.000000
# mean    44.220000  100.844444
# std     24.878931    2.054926
# min      5.000000   98.000000
# 25%     20.000000   99.000000
# 50%     45.000000  101.000000
# 75%     66.500000  102.750000
# max     84.000000  104.000000

# %%
df.info()    ## Shows the Info of data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        100 non-null    int64
#  1   gender     100 non-null    object
#  2   fever      90 non-null     float64
#  3   cough      100 non-null    object
#  4   city       100 non-null    object
#  5   has_covid  100 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.8+ KB

# %%
df.head(2)    ## Shows the first two datas
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
df['fever'] = df['fever'].fillna(df['fever'].mean())

# %%
df.isnull().sum()
# Out:
# age          0
# gender       0
# fever        0
# cough        0
# city         0
# has_covid    0
# dtype: int64

# %%
## Loc() and iloc()
# df.loc[rowrange, column_name]  ---> Start and ending values both included
# df.iloc[row_range, column_range]  ---> Start value included but last value excluded

# %%
df.loc[5:10, ['age', 'fever', 'cough']]
df.loc[10:15, ['age', 'fever', 'cough']]
# Out:
#     age       fever   cough
# 10   75  100.844444    Mild
# 11   65   98.000000    Mild
# 12   25   99.000000  Strong
# 13   64  102.000000    Mild
# 14   51  104.000000    Mild
# 15   70  103.000000  Strong

# %%
df.iloc[5:10, [0,2]] = 55

# %%
df.head(11)
# Out:
#    age  gender       fever   cough       city has_covid
# 0   60    Male       103.0    Mild    Kolkata        No
# 1   27    Male       100.0    Mild      Delhi       Yes
# 2   42    Male       101.0    Mild      Delhi        No
# 3   31  Female        98.0    Mild    Kolkata        No
# 4   65  Female       101.0    Mild     Mumbai        No
# 5   55  Female          55    Mild  Bangalore       Yes
# 6   55    Male          55  Strong  Bangalore        No
# 7   55  Female          55  Strong     Mumbai       Yes
# 8   55  Female          55  Strong  Bangalore        No
# 9   55  Female          55    Mild      Delhi        No
# 10  75  Female  100.844444    Mild      Delhi        No

# %%
print(df['gender'].value_counts())
print("\n")
# print(df['age'].value_counts())
# Out:
# gender
# Female    59
# Male      41
# Name: count, dtype: int64

# %%
df.head(2)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes

# %%
df['gender'] = df['gender'].map({"Male" : 0, "Female" : 1})
df['cough'] = df['cough'].map({"Mild" : 0, "Strong" : 1})
df["has_covid"] = df['has_covid'].map({"Yes" : 1, "No" : 0})

# %%
df.sample(3)
# Out:
#     age  gender  fever  cough       city  has_covid
# 50   19       0  101.0      0      Delhi          1
# 34   74       0  102.0      0     Mumbai          1
# 63   10       0  100.0      0  Bangalore          0

# %%
## To delete a Column
df.drop(columns= ["city"])    ## It makes a shallow copy and delete the mentioned column
# Out:
#     age  gender  fever  cough  has_covid
# 0    60       0  103.0      0          0
# 1    27       0  100.0      0          1
# 2    42       0  101.0      0          0
# 3    31       1   98.0      0          0
# 4    65       1  101.0      0          0
# ..  ...     ...    ...    ...        ...
# 95   12       1  104.0      0          0
# 96   51       1  101.0      1          1
# 97   20       1  101.0      0          0
# 98    5       1   98.0      1          0
# 99   10       1   98.0      1          1
#
# [100 rows x 5 columns]

# %%
df = df.drop(columns= ["city"])    ## It makes a deep copy and also deletes the data from the original table
df
# Out:
#     age  gender  fever  cough  has_covid
# 0    60       0  103.0      0          0
# 1    27       0  100.0      0          1
# 2    42       0  101.0      0          0
# 3    31       1   98.0      0          0
# 4    65       1  101.0      0          0
# ..  ...     ...    ...    ...        ...
# 95   12       1  104.0      0          0
# 96   51       1  101.0      1          1
# 97   20       1  101.0      0          0
# 98    5       1   98.0      1          0
# 99   10       1   98.0      1          1
#
# [100 rows x 5 columns]

# %%
df.sort_index()    ## Sorts the data
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df = df.rename(columns = {"cough" : "updated_cough"})
df
# Out:
#     age  gender  fever  updated_cough  has_covid
# 0    60       0  103.0              0          0
# 1    27       0  100.0              0          1
# 2    42       0  101.0              0          0
# 3    31       1   98.0              0          0
# 4    65       1  101.0              0          0
# ..  ...     ...    ...            ...        ...
# 95   12       1  104.0              0          0
# 96   51       1  101.0              1          1
# 97   20       1  101.0              0          0
# 98    5       1   98.0              1          0
# 99   10       1   98.0              1          1
#
# [100 rows x 5 columns]

# %%
## name of the columns and rows are case sensitive
df["Age"] = df['age'].add(10)
df.head(5)
# Out:
#    age  gender  fever  updated_cough  has_covid  Age
# 0   60       0  103.0              0          0   70
# 1   27       0  100.0              0          1   37
# 2   42       0  101.0              0          0   52
# 3   31       1   98.0              0          0   41
# 4   65       1  101.0              0          0   75

# %%
df['fever'] = df['fever'].sub(100)
# Out:
#    age  gender  fever  updated_cough  has_covid  Age
# 0   60       0    3.0              0          0   70
# 1   27       0    0.0              0          1   37

# %%
df.head(10)
# Out:
#    age  gender  fever  updated_cough  has_covid  Age
# 0   60       0    3.0              0          0   70
# 1   27       0    0.0              0          1   37
# 2   42       0    1.0              0          0   52
# 3   31       1   -2.0              0          0   41
# 4   65       1    1.0              0          0   75
# 5   55       1  -45.0              0          1   65
# 6   55       0  -45.0              1          0   65
# 7   55       1  -45.0              1          1   65
# 8   55       1  -45.0              1          0   65
# 9   55       1  -45.0              0          0   65

# %%
df = df.drop(columns = ["Age"])

# %%
df.head(2)
# Out:
#    age  gender  fever  updated_cough  has_covid
# 0   60       0    3.0              0          0
# 1   27       0    0.0              0          1

# %%
df[['age', 'fever']]   ## Using this method we can filter the data
# Out:
#     age  fever
# 0    60    3.0
# 1    27    0.0
# 2    42    1.0
# 3    31   -2.0
# 4    65    1.0
# ..  ...    ...
# 95   12    4.0
# 96   51    1.0
# 97   20    1.0
# 98    5   -2.0
# 99   10   -2.0
#
# [100 rows x 2 columns]
