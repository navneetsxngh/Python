# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\singh\OneDrive\Desktop\Python\Data\placement.csv")
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.sample()
# Out:
#     cgpa  resume_score  placed
# 67  6.59          6.81       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
df.describe()
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
top_left = df.iloc[:4,:3]
top_left
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1

# %%
cgpa_placed = df.loc[:,["cgpa","placed"]]
cgpa_placed
# Out:
#     cgpa  placed
# 0   8.14       1
# 1   6.17       0
# 2   8.27       1
# 3   6.88       1
# 4   7.52       1
# ..   ...     ...
# 95  6.33       0
# 96  8.23       1
# 97  6.65       0
# 98  8.14       1
# 99  6.09       0
#
# [100 rows x 2 columns]

# %%
s = df.axes            # df.shape
s
df.shape
# Out:
# (100, 3)

# %%
p = df.dtypes
p
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
b = df.empty          #return true ==> have any missing valuse
b
# Out:
# False

# %%
df.isnull().sum()
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
df = df.dropna()  # for remove missing rows

# %%
df.ndim    #No of axis
# Out:
# 2

# %%
df.shape
df.shape[0]         #total rows
df.shape[1]         #total columns
# Out:
# 3

# %%
df.size # row count * column count
# Out:
# 300

# %%
df.values       # get a numpy array for df
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
df = df.copy()

# %%
p = df.sort_values(by = 'resume_score')
p
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
p = df.sort_values(by = 'resume_score',ascending=False)
p
# Out:
#     cgpa  resume_score  placed
# 69  8.06          9.06       1
# 2   8.27          8.86       1
# 65  6.04          8.75       0
# 38  6.00          8.72       0
# 17  7.81          8.71       1
# ..   ...           ...     ...
# 1   6.17          5.17       0
# 41  8.68          5.15       1
# 13  8.50          5.09       1
# 87  5.62          5.05       0
# 94  8.01          4.95       1
#
# [100 rows x 3 columns]

# %%
df['cgpa'] = df['cgpa'].astype(str)
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.dtypes
# Out:
# cgpa             object
# resume_score    float64
# placed            int64
# dtype: object

# %%
df['resume_score'] = df['resume_score'].astype(int)

# %%
df.dtypes
# Out:
# cgpa            object
# resume_score     int64
# placed           int64
# dtype: object

# %%
df['resume_score'] = df['resume_score'].add(4)

# %%
df['resume_score'] = df['resume_score'].sub(4)

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df['cgpa'] = df['cgpa'].astype(float)

# %%
df.count()
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
df.max()
# Out:
# cgpa            9.40
# resume_score    9.06
# placed          1.00
# dtype: float64

# %%
df.min()
# Out:
# cgpa            5.27
# resume_score    4.00
# placed          0.00
# dtype: float64

# %%
g = df.filter(items=['cgpa','placed'])
g
# Out:
#     cgpa  placed
# 0   8.14       1
# 1   6.17       0
# 2   8.27       1
# 3   6.88       1
# 4   7.52       1
# ..   ...     ...
# 95  6.33       0
# 96  8.23       1
# 97  6.65       0
# 98  8.14       1
# 99  6.09       0
#
# [100 rows x 2 columns]

# %%
df[['cgpa','placed']]
# Out:
#     cgpa  placed
# 0   8.14       1
# 1   6.17       0
# 2   8.27       1
# 3   6.88       1
# 4   7.52       1
# ..   ...     ...
# 95  6.33       0
# 96  8.23       1
# 97  6.65       0
# 98  8.14       1
# 99  6.09       0
#
# [100 rows x 2 columns]

# %%
s = df.filter(items = [5,6],axis=0) # axis = 0 means rowwiseoperation
s
# Out:
#    cgpa  resume_score  placed
# 5  8.77             6       1
# 6  5.34             7       0

# %%
t = df.filter(like = '5',axis = 0)
t
# Out:
#     cgpa  resume_score  placed
# 5   8.77             6       1
# 15  8.88             5       1
# 25  7.76             5       1
# 35  8.07             7       1
# 45  8.10             5       1
# 50  8.22             6       1
# 51  6.54             7       0
# 52  5.90             7       0
# 53  6.00             7       0
# 54  5.92             7       0
# 55  6.94             6       1
# 56  6.13             6       0
# 57  6.34             7       0
# 58  6.47             7       0
# 59  5.95             7       0
# 65  6.04             8       0
# 75  6.34             7       1
# 85  6.72             5       0
# 95  6.33             6       0

# %%
p = df.rename(columns={'cgpa':'updated_cgpa',
                       'resume_score': 'semester_marks'})

# %%
df['half'] = df['cgpa'].where(df['cgpa']>7,other = 0)
df.head(10)
# Out:
#    cgpa  resume_score  placed  half
# 0  8.14          6.52       1  8.14
# 1  6.17          5.17       0  0.00
# 2  8.27          8.86       1  8.27
# 3  6.88          7.27       1  0.00
# 4  7.52          7.30       1  7.52
# 5  8.77          6.19       1  8.77
# 6  5.34          7.09       0  0.00
# 7  6.56          6.29       0  0.00
# 8  6.32          6.71       0  0.00
# 9  7.69          7.12       1  7.69

# %%
df.groupby('placed').size()                         # it returns number of rows
# Out:
# placed
# 0    50
# 1    50
# dtype: int64
